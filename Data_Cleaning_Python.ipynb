# %% [markdown]
# ## Importing important libraries

# %%
import pandas as pd

# %% [markdown]
# ## Reading stack exchange data acquired in pandas dataframe

# %%
df=pd.read_csv("C:/Users/Haresh/Desktop/Assignments/Cloud Technology/csv/QueryResults (1).csv")

# %%
df1=pd.read_csv("C:/Users/Haresh/Desktop/Assignments/Cloud Technology/csv/QueryResults (2).csv")

# %%
df2=pd.read_csv("C:/Users/Haresh/Desktop/Assignments/Cloud Technology/csv/QueryResults (3).csv")

# %%
df3=pd.read_csv("C:/Users/Haresh/Desktop/Assignments/Cloud Technology/csv/QueryResults (4).csv")

# %%
df.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0    927358           1          927386.0       NaN  2009-05-29 18:09:14
# 1   2003505           1         2003515.0       NaN  2010-01-05 01:12:15
# 2   5767325           1         5767357.0       NaN  2011-04-23 22:17:18
# 3  16956810           1        16957078.0       NaN  2013-06-06 08:06:45
# 4   2906582           1         2906586.0       NaN  2010-05-25 16:39:47
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN  23303   10030841
# 1           NaN  18475    9258686
# 2           NaN   9899    8897394
# 3           NaN   6286    8203000
# 4           NaN   2298    7782563
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I accidentally <strong>committed the wrong ...      89904.0  ...
# 1  <p>I want to delete a branch both locally and ...      95592.0  ...
# 2  <p>I have an array of numbers and I'm using th...     364969.0  ...
# ...

# %%
df1.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  47772157           1        47793764.0       NaN  2017-12-12 12:01:59
# 1  37306672           1               NaN       NaN  2016-05-18 17:39:46
# 2  22700728           1        41141129.0       NaN  2014-03-27 22:39:46
# 3     70272           1           70296.0       NaN  2008-09-16 08:10:53
# 4   2643462           1         2643598.0       NaN  2010-04-15 07:39:40
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN     50     127400
# 1           NaN     97     127397
# 2           NaN     78     127395
# 3           NaN     77     127392
# 4           NaN     23     127391
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I'm on a windows machine without admin righ...    2344958.0  ...
# 1  <p>Just installed Visual Studio Code 1.1.1 on ...    1864541.0  ...
# 2  <p>i ran in a problem using composer for insta...    1315408.0  ...
# ...

# %%
df2.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  15895266           1               NaN       NaN  2013-04-09 06:56:00
# 1   6974231           1        52629824.0       NaN  2011-08-07 16:53:48
# 2  13454699           1        13455078.0       NaN  2012-11-19 13:22:45
# 3   1806585           1         1806597.0       NaN  2009-11-27 03:16:22
# 4   2950971           1         2951046.0       NaN  2010-06-01 15:18:31
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN     12      74594
# 1           NaN    129      74594
# 2           NaN     30      74594
# 3           NaN    229      74592
# 4           NaN     62      74591
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>I am using PHPEXxcel to export an HTML Tabl...    2143432.0  ...
# 1  <p>So, I'm <em>TRYING</em> to release some sof...      46616.0  ...
# 2  <p>I created MVC Application that have 3 diffe...    1437422.0  ...
# ...

# %%
df3.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0   1616822           1         1616825.0       NaN  2009-10-24 03:15:53
# 1  23667528           1               NaN       NaN  2014-05-15 00:52:26
# 2  12486488           1        12486522.0       NaN  2012-09-18 23:23:42
# 3   5606747           1         5606776.0       NaN  2011-04-09 17:50:07
# 4   5279079           1         5533882.0       NaN  2011-03-11 22:31:43
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN      3      53209
# 1           NaN     25      53209
# 2           NaN      3      53209
# 3           NaN     14      53209
# 4           NaN     18      53209
#
#                                                 Body  OwnerUserId  ...  \
# 0  <p>Why <code>&lt;div style="width:50%" /&gt;</...      90096.0  ...
# 1  <p>Why doesn't <code>:not(:last-of-type)</code...          NaN  ...
# 2  <p>I'd like to change the color of my navbar f...    1379955.0  ...
# ...

# %%
col_list = list(df)
print (col_list)
# Out:
# ['Id', 'PostTypeId', 'AcceptedAnswerId', 'ParentId', 'CreationDate', 'DeletionDate', 'Score', 'ViewCount', 'Body', 'OwnerUserId', 'OwnerDisplayName', 'LastEditorUserId', 'LastEditorDisplayName', 'LastEditDate', 'LastActivityDate', 'Title', 'Tags', 'AnswerCount', 'CommentCount', 'FavoriteCount', 'ClosedDate', 'CommunityOwnedDate', 'ContentLicense']

# %%
df.isnull().sum()
# Out:
# Id                           0
# PostTypeId                   0
# AcceptedAnswerId          7742
# ParentId                 50000
# CreationDate                 0
# DeletionDate             50000
# Score                        0
# ViewCount                    0
# Body                         0
# OwnerUserId               1434
# OwnerDisplayName         44712
# LastEditorUserId          6742
# LastEditorDisplayName    46663
# LastEditDate              6194
# LastActivityDate             0
# Title                        0
# Tags                         0
# AnswerCount                  0
# CommentCount                 0
# FavoriteCount               91
# ClosedDate               45344
# CommunityOwnedDate       49523
# ContentLicense               0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Importing beautifulsoup for working on html tags

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# ### Creating function rm_tags to remove html tags from the data

# %%
def rm_tags(raw_html):
   clean=BeautifulSoup(raw_html, "lxml").text
   return clean

# %%
df["Body"]=df["Body"].apply(rm_tags)

# %%
df1["Body"]=df1["Body"].apply(rm_tags)

# %%
df2["Body"]=df2["Body"].apply(rm_tags)

# %%
df3["Body"]=df3["Body"].apply(rm_tags)

# %%
df.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0    927358           1          927386.0       NaN  2009-05-29 18:09:14
# 1   2003505           1         2003515.0       NaN  2010-01-05 01:12:15
# 2   5767325           1         5767357.0       NaN  2011-04-23 22:17:18
# 3  16956810           1        16957078.0       NaN  2013-06-06 08:06:45
# 4   2906582           1         2906586.0       NaN  2010-05-25 16:39:47
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN  23303   10030841
# 1           NaN  18475    9258686
# 2           NaN   9899    8897394
# 3           NaN   6286    8203000
# 4           NaN   2298    7782563
#
#                                                 Body  OwnerUserId  ...  \
# 0  I accidentally committed the wrong files to Gi...      89904.0  ...
# 1  I want to delete a branch both locally and rem...      95592.0  ...
# 2  I have an array of numbers and I'm using the ....     364969.0  ...
# ...

# %%
df1.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  47772157           1        47793764.0       NaN  2017-12-12 12:01:59
# 1  37306672           1               NaN       NaN  2016-05-18 17:39:46
# 2  22700728           1        41141129.0       NaN  2014-03-27 22:39:46
# 3     70272           1           70296.0       NaN  2008-09-16 08:10:53
# 4   2643462           1         2643598.0       NaN  2010-04-15 07:39:40
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN     50     127400
# 1           NaN     97     127397
# 2           NaN     78     127395
# 3           NaN     77     127392
# 4           NaN     23     127391
#
#                                                 Body  OwnerUserId  ...  \
# 0  I'm on a windows machine without admin right a...    2344958.0  ...
# 1  Just installed Visual Studio Code 1.1.1 on a W...    1864541.0  ...
# 2  i ran in a problem using composer for installi...    1315408.0  ...
# ...

# %%
df2.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0  15895266           1               NaN       NaN  2013-04-09 06:56:00
# 1   6974231           1        52629824.0       NaN  2011-08-07 16:53:48
# 2  13454699           1        13455078.0       NaN  2012-11-19 13:22:45
# 3   1806585           1         1806597.0       NaN  2009-11-27 03:16:22
# 4   2950971           1         2951046.0       NaN  2010-06-01 15:18:31
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN     12      74594
# 1           NaN    129      74594
# 2           NaN     30      74594
# 3           NaN    229      74592
# 4           NaN     62      74591
#
#                                                 Body  OwnerUserId  ...  \
# 0  I am using PHPEXxcel to export an HTML Table g...    2143432.0  ...
# 1  So, I'm TRYING to release some software but Pr...      46616.0  ...
# 2  I created MVC Application that have 3 differen...    1437422.0  ...
# ...

# %%
df3.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0   1616822           1         1616825.0       NaN  2009-10-24 03:15:53
# 1  23667528           1               NaN       NaN  2014-05-15 00:52:26
# 2  12486488           1        12486522.0       NaN  2012-09-18 23:23:42
# 3   5606747           1         5606776.0       NaN  2011-04-09 17:50:07
# 4   5279079           1         5533882.0       NaN  2011-03-11 22:31:43
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN      3      53209
# 1           NaN     25      53209
# 2           NaN      3      53209
# 3           NaN     14      53209
# 4           NaN     18      53209
#
#                                                 Body  OwnerUserId  ...  \
# 0  Why <div style="width:50%" /> is not rendered ...      90096.0  ...
# 1  Why doesn't :not(:last-of-type) work in the fo...          NaN  ...
# 2  I'd like to change the color of my navbar fixe...    1379955.0  ...
# ...

# %% [markdown]
# ### Importing Regular expression module

# %%
import re
import string

# %% [markdown]
# ### Defining function rm_punc to remove punctuations from the data

# %%
def rm_punc(word):
   pattern = r'[' + string.punctuation + ']'
   return re.sub(pattern, '', word)

# %%
df["Body"]=df["Body"].apply(rm_punc)

# %%
df1["Body"]=df1["Body"].apply(rm_punc)
df2["Body"]=df2["Body"].apply(rm_punc)
df3["Body"]=df3["Body"].apply(rm_punc)

# %%
df["Title"]=df["Title"].apply(rm_punc)

# %%
df1["Title"]=df1["Title"].apply(rm_punc)
df2["Title"]=df2["Title"].apply(rm_punc)
df3["Title"]=df3["Title"].apply(rm_punc)

# %%
df.head()
# Out:
#          Id  PostTypeId  AcceptedAnswerId  ParentId         CreationDate  \
# 0    927358           1          927386.0       NaN  2009-05-29 18:09:14
# 1   2003505           1         2003515.0       NaN  2010-01-05 01:12:15
# 2   5767325           1         5767357.0       NaN  2011-04-23 22:17:18
# 3  16956810           1        16957078.0       NaN  2013-06-06 08:06:45
# 4   2906582           1         2906586.0       NaN  2010-05-25 16:39:47
#
#    DeletionDate  Score  ViewCount  \
# 0           NaN  23303   10030841
# 1           NaN  18475    9258686
# 2           NaN   9899    8897394
# 3           NaN   6286    8203000
# 4           NaN   2298    7782563
#
#                                                 Body  OwnerUserId  ...  \
# 0  I accidentally committed the wrong files to Gi...      89904.0  ...
# 1  I want to delete a branch both locally and rem...      95592.0  ...
# 2  I have an array of numbers and Im using the pu...     364969.0  ...
# ...

# %% [markdown]
# ### Replacing \n new line, \t tab, \r carriagereturn, \b backspace, \f form feed

# %%
df = df.replace(r'\n',' ', regex=True)
df = df.replace(r'\t',' ', regex=True)
df = df.replace(r'\r',' ', regex=True)
df = df.replace(r'\b',' ', regex=True)
df = df.replace(r'\f',' ', regex=True)

# %%
df1 = df1.replace(r'\n',' ', regex=True)
df1 = df1.replace(r'\t',' ', regex=True)
df1 = df1.replace(r'\r',' ', regex=True)
df1 = df1.replace(r'\b',' ', regex=True)
df1 = df1.replace(r'\f',' ', regex=True)

# %%
df2 = df2.replace(r'\n',' ', regex=True)
df2 = df2.replace(r'\t',' ', regex=True)
df2 = df2.replace(r'\r',' ', regex=True)
df2 = df2.replace(r'\b',' ', regex=True)
df2 = df2.replace(r'\f',' ', regex=True)

# %%
df3 = df3.replace(r'\n',' ', regex=True)
df3 = df3.replace(r'\t',' ', regex=True)
df3 = df3.replace(r'\r',' ', regex=True)
df3 = df3.replace(r'\b',' ', regex=True)
df3 = df3.replace(r'\f',' ', regex=True)

# %% [markdown]
# ## Downloading clean data as csv file

# %%
df.to_csv("clean_data_csv.csv")
df1.to_csv("clean_data_csv1.csv")
df2.to_csv("clean_data_csv2.csv")
df3.to_csv("clean_data_csv3.csv")

# %% [markdown]
# ## Downloading clean data as text file

# %%
df.to_csv("clean_data.txt")
df1.to_csv("clean_data1.txt")
df2.to_csv("clean_data2.txt")
df3.to_csv("clean_data3.txt")
